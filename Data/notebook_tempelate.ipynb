# %%
import data_utils

# %%
json_path = Path("") # Change to your JSON file
images_root = Path("") # Change to your training images folder
output_folder = Path("") # Change to your output folder

# %%
organize_train_data(json_path, images_root, output_folder)

# %%
json_path = Path("") # Change to your JSON file
images_root = Path("") # Change to your val & test images folder
output_folder = Path("") # Change to your output folder

# %%
val_test_split(json_path, images_root, output_folder, split_ratio=0.8)

# %%
for f in os.listdir(output_folder):
    if f.endswith(".json"):
        json_file = Path(output_folder) / f
        output_sub_folder =Path(output_folder) / Path(f).stem
        bdd_to_yolo(json_file, output_sub_folder, categories)
